# %% [markdown]
# **XML Shema** - describing a "contract" as to what is acceptable XML.

# %%
from IPython.display import Image
Image(filename="8th.jpg")

# %%
Image(filename="9th.jpg")

# %%
Image(filename="10th.jpg")

# %% [markdown]
# ## XSD XML Schema (W3C spec)
# * World Wide Web Consortium (W3C) version
# * It is often called "W3C Schema" becayse "Schema" is considered generic
# * More commonly it is called XSD because the file names end in .xsd

# %%
Image(filename="11.jpg")
